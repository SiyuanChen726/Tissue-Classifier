# %%
import os
import pandas as pd
import numpy as np
import openslide
import matplotlib.pyplot as plt
from utils import get_TC, parse_patch_size, run_TC_one_slide
from utils import process_TCmask, bbx_overlay, get_roi_ids
from utils import parse_roi_id, show_roi, save_patchcsv

# %%
wsi_pt = '/scratch/prj/cb_normalbreast/Siyuan/WSIs/BRCA2_SGK/K108383.svs'
mask_pt = '/scratch/prj/cb_normalbreast/Siyuan/WSI_QC/BRCA2_SGK/K108383.svs/K108383.svs_mask_use.png'
temp = '/scratch/prj/cb_normalbreast/Siyuan/temp'
weights = '/scratch/users/k21066795/prj_normal/ckpts/Tissue_Classifier.h5'

TC_maskpt = f"{temp}/TCprobmask.npy"
TC = get_TC(weights)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
wsi = openslide.OpenSlide(wsi_pt)
img = wsi.read_region((0,0), wsi.level_count-1, wsi.level_dimensions[wsi.level_count-1]).convert('RGB')
plt.imshow(np.array(img))

# %%
tissue_map = run_TC_one_slide(wsi, mask_pt, TC, temp, patch_size=128, foreground_thes=0.7)              
np.save(f"{temp}/TCprobmask.npy", tissue_map)
plt.imshow(tissue_map)
# Out:
# (73703, 32286), (140, 61) compressed, in which 270 tissue tiles.
# Tiles are extracted at level 0, with a size of 524
# and a stride of 524 and downsampled with a factor of 1.
# 95.48977303504944 seconds to vectorise the slide!
# Tissue-Classifier is predicting ...
# /scratch/users/k21066795/prj_normal/Tissue-Classifier/utils.py:217: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   tc_predictions = TC.predict_generator(generator=wsi_sequence, steps=len(wsi_sequence),verbose=1)
# 2024-08-17 06:28:41.284821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8800
# 2024-08-17 06:28:45.947772: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 34/34 [==============================] - 14s 57ms/step

# %%
epi_mask, roi_width, wsi_mask_ratio = process_TCmask(wsi_pt, 
                                                     TC_maskpt, 
                                                     upsample=32, 
                                                     small_objects=100000, 
                                                     roi_width=250)
plt.imshow(epi_mask)

# %%
bbx_map = bbx_overlay(epi_mask=epi_mask, overlay_pt=f"{temp}/bbx.png", roi_width=roi_width) 
plt.imshow(bbx_map)

# %%
wsi_id = os.path.basename(wsi_pt).split('.')[0]
roi_ids = get_roi_ids(epi_mask, wsi_id, roi_width=roi_width, 
                      upsample=32, wsi_mask_ratio=wsi_mask_ratio)
im = show_roi(wsi, roi_ids[6])
plt.imshow(im)
plt.axis('off')
# Out:
# There're 10 ROIs detected

# %%
patch_size, _ = parse_patch_size(wsi, patch_size=patch_size)
print(patch_size)
patch_df = save_patchcsv(roi_ids, patch_size, TC_maskpt, temp)
print(patch_df)
# Out:
# /scratch/prj/cb_normalbreast/Siyuan/temp/K108383_patch.csv saved!
#                          roi_id                               patch_id  \
# 26  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_29_259
# 27  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_30_259
# 28  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_34_259
# 29  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_28_259
# 30  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_28_259
# 31  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_28_259
# 32  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_28_259
# 33  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_29_259
# 34  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_29_259
# 35  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_29_259
# 36  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_34_30_259
# 37  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_30_259
# 38  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_30_259
# 39  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_30_259
# 40  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_31_259
# 41  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_31_259
# 42  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_31_259
# 43  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_31_259
# 44  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_32_259
# 45  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_32_259
# 46  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_32_259
# 47  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_33_259
# 48  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_33_259
# 49  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_33_259
# 50  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_33_259
# 51  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_32_34_259
# 52  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_33_34_259
# 53  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_34_34_259
# 54  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_35_34_259
# 55  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_34_259
# 56  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_34_259
# 57  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_35_259
# 58  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_35_259
# 59  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_35_259
# 60  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_36_36_259
# 61  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_37_36_259
# 62  K108383_8192_7139_2023_2549  K108383_8192_7139_2023_2549_38_36_259
#
#            cls    TC_epi    TC_str    TC_adi cohort wsi_id
# 26  epithelium  0.679325  0.320528  0.000147   temp   temp
# 27  epithelium  0.886679  0.112744  0.000577   temp   temp
# 28  epithelium  0.975227  0.024755  0.000019   temp   temp
# 29      stroma  0.001211  0.903658  0.095131   temp   temp
# 30      stroma  0.032095  0.957192  0.010713   temp   temp
# 31      stroma  0.026887  0.939416  0.033697   temp   temp
# 32      stroma  0.065562  0.931520  0.002918   temp   temp
# 33      stroma  0.036022  0.960074  0.003904   temp   temp
# 34      stroma  0.026342  0.953438  0.020220   temp   temp
# 35      stroma  0.005006  0.990064  0.004930   temp   temp
# 36      stroma  0.111806  0.882617  0.005577   temp   temp
# 37      stroma  0.000757  0.998490  0.000753   temp   temp
# 38      stroma  0.003946  0.995283  0.000771   temp   temp
# 39      stroma  0.004733  0.995169  0.000097   temp   temp
# 40      stroma  0.001210  0.990164  0.008626   temp   temp
# 41      stroma  0.031613  0.968191  0.000197   temp   temp
# 42      stroma  0.019886  0.979580  0.000534   temp   temp
# 43      stroma  0.053795  0.943692  0.002514   temp   temp
# 44      stroma  0.013712  0.985041  0.001246   temp   temp
# 45      stroma  0.009543  0.989112  0.001345   temp   temp
# 46      stroma  0.000788  0.999003  0.000209   temp   temp
# 47      stroma  0.054970  0.888030  0.057000   temp   temp
# 48      stroma  0.011600  0.972489  0.015911   temp   temp
# 49      stroma  0.033003  0.965301  0.001696   temp   temp
# 50      stroma  0.001606  0.998256  0.000138   temp   temp
# 51      stroma  0.163755  0.787537  0.048708   temp   temp
# 52      stroma  0.078167  0.711912  0.209921   temp   temp
# 53      stroma  0.030079  0.903749  0.066172   temp   temp
# 54      stroma  0.050551  0.914788  0.034661   temp   temp
# 55      stroma  0.024108  0.975142  0.000750   temp   temp
# 56      stroma  0.487087  0.511961  0.000953   temp   temp
# 57      stroma  0.000533  0.999358  0.000110   temp   temp
# 58      stroma  0.075030  0.922697  0.002272   temp   temp
# 59      stroma  0.416014  0.578884  0.005102   temp   temp
# 60      stroma  0.004111  0.991612  0.004277   temp   temp
# 61      stroma  0.000084  0.999868  0.000048   temp   temp
# 62      stroma  0.000888  0.998961  0.000151   temp   temp

# %%
patch_id = list(patch_df['patch_id'][patch_df['cls']=='epithelium'])[2]
show_patch(wsi, patch_id)
plt.axis('off')
# Out:
# 26    K108383_8192_7139_2023_2549_38_29_259
# 27    K108383_8192_7139_2023_2549_38_30_259
# 28    K108383_8192_7139_2023_2549_37_34_259
# Name: patch_id, dtype: object
